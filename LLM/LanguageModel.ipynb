# %% [markdown]
# ## 언어 모델(Language Model)

# %% [markdown]
# 단어 시퀀스에 확률을 할당(assign) 하는 일을 하는 모델.
#
# 조금 풀어서 쓰면, 언어 모델은 가장 자연스러운 단어 시퀀스를 찾아내는 모델이다.
#
# 가장 보편적으로 사용되는 방법은 언어 모델이 이전 단어들이 주어졌을 때 다음 단어를 예측해내는 방법이다.

# %% [markdown]
#     비행기를 타려고 공항에 갔는데 지각을 하는 바람에 비행기를 [?]
#
# 앞 단어들을 기반으로 뒤 ?에 들어갈 "놓쳤다"를 예측할 수 있다.

# %% [markdown]
# ### 조건부확률

# %% [markdown]
# 사건 $A$가 일어났을 때 사건 $B$가 일어날 확률을
#
# $$ P(B|A) = \frac{P(A\cap B)}{P(A)} $$
#
# 라고 하며, 이 식을 변형하면
#
# $$ P(A\cap B) = P(A)P(B|A) $$
#
# 가 된다.
#
# 이를 더 일반화하면
#
# $$ P(A\cap B\cap C\cap D) = P(A)P(B|A)P(C|A\cap B)P(D|A\cap B\cap C)$$

# %% [markdown]
# 마찬가지로 이를 문장에 적용시켜 보면
#
# 문장 'An adorable little boy is spreading smiles'의 확률은
#
#
#     P(An adorable little boy is spreading smiles) =
#     P(An) × P(adorable|An) × P(little|An adorable) × P(boy|An adorable little) × P(is|An adorable little boy)
#     × P(spreading|An adorable little boy is) × P(smiles|An adorable little boy is spreading)

# %% [markdown]
# P( is | An adorable little boy )의 확률은 보통 아래와 같은 방식으로 계산된다.
# $$
# P(is|An\_ adorable\_ little\_ boy) = \frac{count(An\_ adorable\_ little\_ boy\_ is)}{count(An\_ adorable\_ little\_ boy)}
# $$

# %% [markdown]
# An adorable little boy라는 단어 시퀀스가 없었다면 분모가 0이 되어 확률은 정의되지 않는다.
#
# 그렇다고 이 확률을 0 또는 정의되지 않는 확률이라고 하는 것이 정확한 모델링 방법은 아닐 것이다.
#
# 현실에선 An adorable little boy is 라는 단어 시퀀스가 존재하고 또 문법에도 적합하므로 정답일 가능성 또한 높다.
#
# 이와 같이 충분한 데이터를 관측하지 못하여 언어를 정확히 모델링하지 못하는 문제를 **희소 문제(sparsity problem)** 라고 한다.

# %% [markdown]
# ## N-gram 언어모델

# %% [markdown]
# SLM의 한계는 훈련 코퍼스에 확률을 계산하고 싶은 문장이나 단어가 없을 수 있다는 점이다.
#
# 그리고 확률을 계산하고 싶은 문장이 길어질수록 갖고있는 코퍼스에서 그 문장이 존재하지 않을 가능성이 높다.
#
# 그런데 다음과 같이 참고하는 단어들을 줄이면 카운트를 할 수 있을 가능성을 높일 수 있다.

# %% [markdown]
# P( is | An adorable little boy ) $\approx$ P( is | boy )
#
# 혹은
#
# P( is | An adorable little boy ) $\approx$ P( is | little boy )

# %% [markdown]
# 이때 임의의 개수를 정하기 위한 기준을 위해 사용하는 것이 n-gram이며,
#
# n-gram은 n개의 연속적인 단어 나열을 의미한다.

# %% [markdown]
# unigrams : an, adorable, little, boy, is, spreading, smiles
#
# bigrams : an adorable, adorable little, little boy, boy is, is spreading, spreading smiles
#
# trigrams : an adorable little, adorable little boy, little boy is, boy is spreading, is spreading smiles
#
# 4-grams : an adorable little boy, adorable little boy is, little boy is spreading, boy is spreading smiles

# %% [markdown]
# 물론 n-gram도 여전히 희소 문제가 존재한다.

# %% [markdown]
# 텍스트 유사도
#
# [TextSimilarity](TextSimilarity.ipynb)
