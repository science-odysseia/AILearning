# %% [markdown]
# 변수 생성 및 값 대입
#
# `변수 이름` = `대입할 값` 형식

# %%
a = 10

b = 30.4

c = "Hello"

# %% [markdown]
# 주석 : # 기호 사용
#
# ``` python
# #이것은 주석입니다.
# ```
# 이런 식으로 사용

# %%
a = 10          # 정수형

b = 30.4        # 실수형

b1 = 30.0       # 실수형(30은 정수형, 30.0은 실수형)

c = "Hello"     # 문자열형

# %% [markdown]
# 출력 : print()
#
# 대소문자 구분 필수.
#
# PRINT(), Print() 안됨.

# %%
print(a)

print(b)

print(c)

print()
# Out:
# 10
# 30.4
# Hello
